# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = np.load("./model_ori.pkl", allow_pickle=True)

data
# Out:
#                                Accuracy  Balanced Accuracy   ROC AUC  \
# Model
# NearestCentroid                0.805647           0.789807  0.789807
# BernoulliNB                    0.804334           0.783903  0.783903
# ExtraTreesClassifier           0.797768           0.777587  0.777587
# LGBMClassifier                 0.784636           0.769715  0.769715
# RandomForestClassifier         0.792515           0.768052  0.768052
# XGBClassifier                  0.783979           0.765375  0.765375
# Perceptron                     0.776756           0.762652  0.762652
# BaggingClassifier              0.774130           0.753025  0.753025
# NuSVC                          0.778070           0.750904  0.750904
# LogisticRegression             0.764281           0.748807  0.748807
# PassiveAggressiveClassifier    0.756402           0.743132  0.743132
# RidgeClassifier                0.749836           0.733445  0.733445
# ...

# %%
data = np.load("./model_encoded.pkl", allow_pickle=True)
data
# Out:
#                                Accuracy  Balanced Accuracy   ROC AUC  \
# Model
# BernoulliNB                    0.808930           0.791477  0.791477
# NearestCentroid                0.803677           0.787496  0.787496
# ExtraTreesClassifier           0.795798           0.777061  0.777061
# XGBClassifier                  0.791202           0.774246  0.774246
# LGBMClassifier                 0.788575           0.773346  0.773346
# RandomForestClassifier         0.786605           0.761515  0.761515
# Perceptron                     0.770847           0.755718  0.755718
# LogisticRegression             0.768221           0.753430  0.753430
# BaggingClassifier              0.771504           0.751530  0.751530
# NuSVC                          0.777413           0.750531  0.750531
# PassiveAggressiveClassifier    0.755089           0.741393  0.741393
# RidgeClassifierCV              0.741300           0.725413  0.725413
# ...

# %%
data = np.load("./model_fin.pkl", allow_pickle=True)
data
# Out:
#                                Accuracy  Balanced Accuracy   ROC AUC  \
# Model
# BernoulliNB                    0.816809           0.801516  0.801516
# NearestCentroid                0.811556           0.796542  0.796542
# ExtraTreesClassifier           0.799737           0.783270  0.783270
# LGBMClassifier                 0.788575           0.773346  0.773346
# XGBClassifier                  0.790545           0.772881  0.772881
# RandomForestClassifier         0.794485           0.771950  0.771950
# NuSVC                          0.793171           0.770211  0.770211
# Perceptron                     0.772160           0.761424  0.761424
# LogisticRegression             0.762311           0.752248  0.752248
# BaggingClassifier              0.764281           0.747022  0.747022
# SVC                            0.778726           0.745923  0.745923
# PassiveAggressiveClassifier    0.755089           0.745558  0.745558
# ...
