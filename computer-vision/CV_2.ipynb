# %% [markdown]
# ## 高斯金字塔
#
# 首先，先读入图像数据、导入必要包

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

src = cv2.imread("Lenna.jpg")
plt.imshow(src[:,:,::-1])
plt.show()

# %% [markdown]
# 高斯金字塔的实现
#
# 在我们的样例代码中，我们使用循环来进行多次进行高斯滤波变换。
#
# 实际上，它完全可以写成更为简洁的递归形式：

# %%
def pyrDown(image,level):
    # recursively pyrDown
    if level == 0:
        return image.copy()
    else:
        return pyrDown(cv2.pyrDown(image.copy()), level-1)

# %%
res = pyrDown(src, 2)
plt.imshow(res[:,:,::-1])

# %%
# 使用拉普拉斯金字塔重建图像
def pyrUp(image,level):
    # recursively pyrUp
    if level == 0:
        return image.copy()
    else:
        return pyrUp(cv2.pyrUp(image.copy()), level-1)

# %%
res_hi = pyrUp(res, 2)
plt.imshow(res_hi[:,:,::-1])
